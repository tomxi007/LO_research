# %%
# %matplotlib inline
from salesPlot import *

# %%
salesPlot('SalesEpoch20160224.csv', Interval.hr, 2*Interval.hr)

# %%
salesPlot('SalesEpoch20160224.csv', Interval.hr, 6*Interval.hr)

# %%
salesPlot('SalesEpoch20160224.csv', Interval.hr, Interval.day)

# %%
salesPlot('SalesEpoch20160224.csv', Interval.sixHr, Interval.day)

# %%
salesPlot('SalesEpoch20160224.csv', Interval.hr, Interval.halfWeek)

# %%
salesPlot('SalesEpoch20160224.csv', Interval.sixHr, Interval.halfWeek)

# %%
salesPlot('SalesEpoch20160224.csv', Interval.day, Interval.halfWeek)

# %%
salesPlot('SalesEpoch20160224.csv', Interval.hr, Interval.week)

# %%
salesPlot('SalesEpoch20160224.csv', Interval.sixHr, Interval.week)

# %%
salesPlot('SalesEpoch20160224.csv', Interval.day, Interval.week)

# %%
salesPlot('SalesEpoch20160224.csv', Interval.hr, Interval.biWeek)

# %%
salesPlot('SalesEpoch20160224.csv', Interval.sixHr, Interval.biWeek)

# %%
salesPlot('SalesEpoch20160224.csv', Interval.day, Interval.biWeek)
